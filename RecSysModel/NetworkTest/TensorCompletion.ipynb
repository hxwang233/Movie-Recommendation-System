# %%
import torch 
from torch import nn
from torch.nn import init
import torch.utils.data as data_utils
from torch.autograd import Variable
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
SEED = 2021
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

# %%
dataset = np.loadtxt(fname='E:/data/Abilene.txt', delimiter="\t", skiprows=1)
N_ORIGIN = int(np.max(dataset[:,0]))
N_DESTINATION = int(np.max(dataset[:,1]))
N_TIME = int(np.max(dataset[:,2]))
EMB_SIZE = 64
NEG_WEIGHT = 0.1
DROP_RATIO = 0.3
LEARNING_RATE = 0.05
BATCH_SIZE = 128
EPOCH = 200
#train_index = np.random.choice(list(range(dataset.shape[0])), size = int(0.3*dataset.shape[0]), replace=False)
#test_index = list(set(range(dataset.shape[0])) - set(train_index))

# %%
flag = np.inf
for i in range(1,N_TIME):
    tmp = len(dataset[dataset[:,2]==i]) / (N_ORIGIN*N_DESTINATION)
    if tmp < flag:
        flag = tmp
print(flag)
# Out:
# 0.6805555555555556

# %%
len(dataset) / (N_ORIGIN*N_DESTINATION*N_TIME)
# Out:
# 0.9493114688969724

# %%
def generate_train_from_local(path, index, n_origin, n_destination, n_time):
    data = np.loadtxt(fname=path, delimiter="\t", skiprows=1)[index,:]
    data[:,:3] = data[:,:3] - 1 
    train_tensor = np.zeros((n_origin, n_destination, n_time))
    for line in data:
        train_tensor[int(line[0]),int(line[1]),int(line[2])] = line[3]
    pos = dict()
    odt = dict()
    max_time_id = train_tensor.shape[2]
    max_time_num = 0
    for o in range(train_tensor.shape[0]):
        for d in range(train_tensor.shape[1]):
            pos_time = list(np.nonzero(train_tensor[o][d])[0])
            pos_time_num = len(pos_time)
            if  pos_time_num > max_time_num:
                max_time_num = pos_time_num
            pos[(o,d)] = pos_time
            odt[(o,d)] = list(train_tensor[o][d][pos_time])
    train_od = list()
    train_y = list()
    train_time = list()
    for i, j in pos.keys():
        while len(pos[(i,j)]) < max_time_num:
            pos[(i,j)].append(max_time_num)
            odt[(i,j)].append(0)
        train_od.append([i,j])
        train_time.append(pos[(i,j)])
        train_y.append(odt[(i,j)])
    return np.array(train_od), np.array(train_time), np.array(train_y)

def generate_test_from_local(path, index):
    data = np.loadtxt(fname=path, delimiter="\t", skiprows=1)[index,:]
    data[:,:3] = data[:,:3] - 1 
    return np.array(data[:,:2]), np.array(data[:,2]), data[:,3]

train_od, train_time, train_y = generate_train_from_local(path="E:/data/Abilene.txt", index = train_index,
                                                               n_origin=N_ORIGIN, n_destination=N_DESTINATION, n_time=N_TIME)
test_od, test_time, test_y = generate_test_from_local(path="E:/data/Abilene.txt", index = test_index)

# %%
class ENMF(nn.Module):
    def __init__(self, emb_size, n_origin, n_destination, n_time, neg_weight, drop_out):
        super().__init__()
        self.n_origin = n_origin
        self.n_destination = n_destination
        self.n_time = n_time
        self.neg_weight = neg_weight
        self.emb_size   = emb_size
        self.origin_embs = nn.Embedding(n_origin, emb_size)
        self.destination_embs = nn.Embedding(n_destination, emb_size)
        self.time_embs = nn.Embedding(n_time+1, emb_size)
        self.h = nn.Parameter(torch.randn(emb_size, 1))
        self.dropout = nn.Dropout(p=drop_out)
        self._reset_para()
        return
    
    def _reset_para(self):
        nn.init.xavier_normal_(self.origin_embs.weight)
        nn.init.xavier_normal_(self.destination_embs.weight)
        nn.init.xavier_normal_(self.time_embs.weight)
        nn.init.constant_(self.h, 0.01)
        return
    
    def forward(self, oids, dids, pos_tids, pos_value):
        '''
        uids: B
        dids: B
        pos_tids: B * L
        pos_value: B * L
        '''
        o_emb = self.dropout(self.origin_embs(oids))
        d_emb = self.dropout(self.destination_embs(dids))
        pos_embs = self.time_embs(pos_tids)

        # torch.einsum("ab,abc->abc")
        # B * L * D
        mask = (~(pos_tids.eq(self.n_time))).float()
        pos_embs = pos_embs * mask.unsqueeze(2)
        
        #pos_value = pos_value * ((~(pos_value.eq(-1))).float()).unsqueeze(2)
        
        # torch.einsum("ac,abc->abc")
        # B * L * D
        odt = o_emb.unsqueeze(1) * d_emb.unsqueeze(1) * pos_embs
        # torch.einsum("ajk,kl->ajl")
        # B * L
        hodt = odt.matmul(self.h).squeeze(2)

        # loss
        #print(odt.size())
        #print(hodt.size())
        #print(pos_value.size())
        pos_data_loss = torch.sum((1 - self.neg_weight) * hodt.square() - 2.0 * hodt * pos_value) # 添加真实值

        # torch.einsum("ab,ac->abc")
        part_1 = self.time_embs.weight.unsqueeze(2).bmm(self.time_embs.weight.unsqueeze(1))
        part_2 = o_emb.unsqueeze(2).bmm(o_emb.unsqueeze(1))
        part_3 = d_emb.unsqueeze(2).bmm(d_emb.unsqueeze(1))
        
        # D * D
        part_1 = part_1.sum(0)
        part_2 = part_2.sum(0)
        part_3 = part_3.sum(0)
        part_4 = self.h.mm(self.h.t())
        all_data_loss = torch.sum(part_1 * part_2 * part_3 * part_4)

        loss = self.neg_weight * all_data_loss + pos_data_loss
        return loss
    
    def predict(self, oid, did):
        '''
        oid: B
        did: B
        '''
        oid_embs = self.origin_embs(oid)
        did_embs = self.destination_embs(did)
        origin_destination_all_times = oid_embs.unsqueeze(1) * did_embs.unsqueeze(1) * self.time_embs.weight
        pred = origin_destination_all_times.matmul(self.h).squeeze(2)
        return torch.relu(pred)
    
'''    def rank(self, user):
        res = self.user_embs(user).unsqueeze(0)
        res = res * self.item_embs.weight
        res = res.matmul(self.h).squeeze(1)
        return res'''
# Out:
# '    def rank(self, user):\n        res = self.user_embs(user).unsqueeze(0)\n        res = res * self.item_embs.weight\n        res = res.matmul(self.h).squeeze(1)\n        return res'

# %%
def createLoader(train_od, train_time, train_y, test_od, test_time, test_y, batch_size):
    torch_x1 = torch.from_numpy(train_od).type(torch.LongTensor)
    torch_x2 = torch.from_numpy(train_time).type(torch.LongTensor)
    torch_y  = torch.from_numpy(train_y).type(torch.FloatTensor)
    torch_test1 = torch.from_numpy(test_od).type(torch.LongTensor)
    torch_test2 = torch.from_numpy(test_time).type(torch.LongTensor)
    torch_test3 = torch.from_numpy(test_y).type(torch.FloatTensor)
    torch_dataset = data_utils.TensorDataset(torch_x1, torch_x2, torch_y)
    train_loader = data_utils.DataLoader(dataset = torch_dataset, batch_size = batch_size, shuffle = True, num_workers = 0)
    torch_testset = data_utils.TensorDataset(torch_test1[:,0], torch_test1[:,1], torch_test2, torch_test3)
    test_loader = data_utils.DataLoader(dataset = torch_testset, batch_size = batch_size, num_workers = 0)
    return train_loader, test_loader

def createModel(emb_size, lr, n_origin, n_destination, n_time, neg_weight, drop_out):
    model = ENMF(emb_size=emb_size, n_origin=n_origin, n_destination=n_destination, n_time=n_time, 
                 neg_weight=neg_weight, drop_out = drop_out)
    if(torch.cuda.is_available()):
        model = model.cuda()
    optimizer = torch.optim.Adagrad(model.parameters(), lr = lr)
    print(model)
    return model, optimizer

# %%
def eval_1(model, test_loader):
    hit_list = list()
    undcg_list = list()
    rank_all_users = list()
    model.eval()
    with torch.no_grad(): 
        rmse_tmp = mae_tmp = ter_tmp = 0
        count = 0
        for step, (batch_o, batch_d, batch_t, batch_y) in enumerate(test_loader):
            if torch.cuda.is_available():
                batch_o, batch_d = batch_o.cuda(), batch_d.cuda()
            prediction = model.predict(batch_o, batch_d)
            pred_vector = prediction.cpu().data.numpy()
            for i, vec in enumerate(pred_vector):
                real = batch_y[i]
                res  = vec[batch_t[i]]
                rmse_tmp += torch.pow((res - real), 2).numpy()
                mae_tmp += torch.abs(res - real).numpy()
                ter_tmp += torch.pow(real, 2).numpy()
                count += 1
        rmse = np.sqrt(rmse_tmp / count)
        mae  = mae_tmp / count
        ter  = np.sqrt(rmse_tmp) / np.sqrt(ter_tmp)
        print(np.sqrt(rmse_tmp))
        print(np.sqrt(ter_tmp))
    model.train()
    print('RMSE:', rmse, ' ≈ %.6f' %  rmse)
    print('MAE :', mae,  ' ≈ %.6f' %  mae)
    print('TER :', ter,  ' ≈ %.6f' %  ter)
    return rmse, mae, ter

# %%
def train(train_od, train_time,train_y, test_od, test_time, test_y, epoch, batch_size, emb_size, lr, drop_out, neg_weight, n_origin, n_destination, n_time): 
    train_loader, test_loader = createLoader(train_od, train_time, train_y, test_od, test_time, test_y, batch_size)
    model, optimizer = createModel(emb_size, lr, n_origin, n_destination, n_time, neg_weight, drop_out)
    train_loss_list = list()
    rmse_list = [.0]
    mae_list = [.0]
    ter_list = [.0]
    model.train()
    for e in range(epoch):
        train_loss = list()
        for step, (batch_x1, batch_x2, batch_y) in enumerate(train_loader):
            x1, x2, x3, y = batch_x1[:,0], batch_x1[:,1], batch_x2, batch_y
            if (torch.cuda.is_available()):
                x1, x2, x3, y = x1.cuda(), x2.cuda(), x3.cuda(), y.cuda()
            optimizer.zero_grad()
            loss = model(x1, x2, x3, y)
            loss.backward()        
            train_loss.append(loss.cpu().item())
            optimizer.step()
        print('------第'+str(e+1)+'个epoch------')
        mean_train_loss = np.mean(train_loss)
        print('train_loss:', mean_train_loss)
        train_loss_list.append(mean_train_loss)
        if (e+1) % 200 == 0:
            rmse, mae, ter = eval_1(model, test_loader)
            rmse_list.append(rmse)
            mae_list.append(mae)
            ter_list.append(ter)
    #np.savetxt("./evalres/enmf/train_loss_list_"+str(epoch)+"epoch.txt", train_loss_list)    
    #np.savetxt("./evalres/enmf/rmse_list_"+str(epoch)+"epoch.txt", rmse_list)
    torch.cuda.empty_cache()
    print('------Finished------')
    return model


EMB_SIZE = 64
NEG_WEIGHT = 0.1
DROP_RATIO = 0.3
LEARNING_RATE = 0.01
BATCH_SIZE = 32
EPOCH = 600
model = train(train_od, train_time, train_y, test_od, test_time, test_y, epoch=EPOCH, batch_size=BATCH_SIZE, emb_size=EMB_SIZE, lr=LEARNING_RATE, 
              drop_out=DROP_RATIO, neg_weight=NEG_WEIGHT, n_origin=N_ORIGIN, n_destination=N_DESTINATION, n_time=N_TIME)
# Out:
# ENMF(
#   (origin_embs): Embedding(12, 64)
#   (destination_embs): Embedding(12, 64)
#   (time_embs): Embedding(48385, 64)
#   (dropout): Dropout(p=0.3, inplace=False)
# )
# ------第1个epoch------
# train_loss: -0.027771917037640315
# ------第2个epoch------
# train_loss: -1.1112172704190015
# ------第3个epoch------
# train_loss: -2.6974470373243093
# ------第4个epoch------
# train_loss: -4.613855094462633
# ------第5个epoch------
# train_loss: -6.841515807807445
# ------第6个epoch------
# train_loss: -7.405362331867218
# ------第7个epoch------
# train_loss: -14.470906600356102
# ------第8个epoch------
# train_loss: -19.90074529647827
# ------第9个epoch------
# train_loss: -15.206150156259536
# ------第10个epoch------
# train_loss: -25.32704668045044
# ------第11个epoch------
# train_loss: -37.05662040114403
# ------第12个epoch------
# train_loss: -22.651872754096985
# ------第13个epoch------
# train_loss: -42.976387155056
# ------第14个epoch------
# train_loss: -52.52664442062378
# ------第15个epoch------
# train_loss: -59.07671785354614
# ------第16个epoch------
# train_loss: -32.38325783610344
# ------第17个epoch------
# train_loss: -59.117933738231656
# ------第18个epoch------
# train_loss: -92.93972216844558
# ------第19个epoch------
# train_loss: -89.42842974662781
# ------第20个epoch------
# train_loss: -92.06162939071655
# ------第21个epoch------
# train_loss: -91.21706948280334
# ------第22个epoch------
# train_loss: -139.71378511190414
# ------第23个epoch------
# train_loss: -120.25669867992401
# ------第24个epoch------
# train_loss: -161.73450508117676
# ------第25个epoch------
# train_loss: -148.96749933362008
# ------第26个epoch------
# train_loss: -201.70871200561524
# ------第27个epoch------
# train_loss: -228.64390796422958
# ------第28个epoch------
# train_loss: -244.3027015209198
# ------第29个epoch------
# train_loss: -221.3491064429283
# ------第30个epoch------
# train_loss: -189.85408334732057
# ------第31个epoch------
# train_loss: -186.37231254577637
# ------第32个epoch------
# train_loss: -238.6899467408657
# ------第33个epoch------
# train_loss: -259.12960119247435
# ------第34个epoch------
# train_loss: -309.2933125972748
# ------第35个epoch------
# train_loss: -306.2817467033863
# ------第36个epoch------
# train_loss: -270.78886716365815
# ------第37个epoch------
# train_loss: -254.10909414291382
# ------第38个epoch------
# train_loss: -400.48186191916466
# ------第39个epoch------
# train_loss: -448.6889132022858
# ------第40个epoch------
# train_loss: -422.7895867109299
# ------第41个epoch------
# train_loss: -422.36255464553835
# ------第42个epoch------
# train_loss: -352.0965535759926
# ------第43个epoch------
# train_loss: -481.0284154891968
# ------第44个epoch------
# train_loss: -454.1918186545372
# ------第45个epoch------
# train_loss: -552.1592873811721
# ------第46个epoch------
# train_loss: -557.4189475297928
# ------第47个epoch------
# train_loss: -580.1253889799118
# ------第48个epoch------
# train_loss: -483.7531611442566
# ------第49个epoch------
# train_loss: -584.5824522018432
# ------第50个epoch------
# train_loss: -712.0754402399064
# ------第51个epoch------
# train_loss: -677.7919354915618
# ------第52个epoch------
# train_loss: -631.4644198179245
# ------第53个epoch------
# train_loss: -791.8752864599228
# ------第54个epoch------
# train_loss: -543.7218132257461
# ------第55个epoch------
# train_loss: -708.542844414711
# ------第56个epoch------
# train_loss: -823.8838048458099
# ------第57个epoch------
# train_loss: -588.1809505462646
# ------第58个epoch------
# train_loss: -712.0941006660462
# ------第59个epoch------
# train_loss: -707.854367518425
# ------第60个epoch------
# train_loss: -1031.9755988121033
# ------第61个epoch------
# train_loss: -913.8459535598755
# ------第62个epoch------
# train_loss: -776.0536360263825
# ------第63个epoch------
# train_loss: -897.1196053504943
# ------第64个epoch------
# train_loss: -1055.0038777828217
# ------第65个epoch------
# train_loss: -1073.1873423814773
# ------第66个epoch------
# train_loss: -930.3098284721375
# ------第67个epoch------
# train_loss: -1278.5310793876647
# ------第68个epoch------
# train_loss: -1169.5049557685852
# ------第69个epoch------
# train_loss: -1205.940022087097
# ------第70个epoch------
# train_loss: -1121.4756699800491
# ------第71个epoch------
# train_loss: -1303.4801961660385
# ------第72个epoch------
# train_loss: -1063.6009847164155
# ------第73个epoch------
# train_loss: -1517.8542131900788
# ------第74个epoch------
# train_loss: -1309.205370426178
# ------第75个epoch------
# train_loss: -1306.6672080039978
# ------第76个epoch------
# train_loss: -1430.2043526649475
# ------第77个epoch------
# train_loss: -1793.580945587158
# ------第78个epoch------
# train_loss: -1710.647196674347
# ------第79个epoch------
# train_loss: -1280.6559876918793
# ------第80个epoch------
# train_loss: -1972.4723242759705
# ------第81个epoch------
# train_loss: -1569.4758855342866
# ------第82个epoch------
# train_loss: -1727.765809392929
# ------第83个epoch------
# train_loss: -1328.9423325061798
# ------第84个epoch------
# train_loss: -2310.9892287969587
# ------第85个epoch------
# train_loss: -2275.4013453722
# ------第86个epoch------
# train_loss: -1759.7643574476242
# ------第87个epoch------
# train_loss: -1528.129244017601
# ------第88个epoch------
# train_loss: -1484.996766281128
# ------第89个epoch------
# train_loss: -2361.930618095398
# ------第90个epoch------
# train_loss: -2210.9085216522217
# ------第91个epoch------
# train_loss: -2016.322466492653
# ------第92个epoch------
# train_loss: -2540.178455686569
# ------第93个epoch------
# train_loss: -2290.735321831703
# ------第94个epoch------
# train_loss: -2024.7983339309692
# ------第95个epoch------
# train_loss: -2225.2387968540193
# ------第96个epoch------
# train_loss: -2034.4140200138092
# ------第97个epoch------
# train_loss: -1517.7543668746948
# ------第98个epoch------
# train_loss: -1998.4690136909485
# ------第99个epoch------
# train_loss: -2114.0547519207003
# ------第100个epoch------
# train_loss: -2976.1471935272216
# ------第101个epoch------
# train_loss: -2571.4763567447662
# ------第102个epoch------
# train_loss: -1778.827057313919
# ------第103个epoch------
# train_loss: -2865.065252304077
# ------第104个epoch------
# train_loss: -2989.8801880836486
# ------第105个epoch------
# train_loss: -2895.1969685077665
# ------第106个epoch------
# train_loss: -2552.3489826202394
# ------第107个epoch------
# train_loss: -3543.905581665039
# ------第108个epoch------
# train_loss: -2270.298073077202
# ------第109个epoch------
# train_loss: -2927.831844508648
# ------第110个epoch------
# train_loss: -3100.2447650194167
# ------第111个epoch------
# train_loss: -2850.8352621555327
# ------第112个epoch------
# train_loss: -2977.998367881775
# ------第113个epoch------
# train_loss: -3129.938571667671
# ------第114个epoch------
# train_loss: -3965.0764700889586
# ------第115个epoch------
# train_loss: -2839.5201275587083
# ------第116个epoch------
# train_loss: -3939.692568588257
# ------第117个epoch------
# train_loss: -3179.422171664238
# ------第118个epoch------
# train_loss: -2692.039086675644
# ------第119个epoch------
# train_loss: -3730.8983437538145
# ------第120个epoch------
# train_loss: -4445.486597633362
# ------第121个epoch------
# train_loss: -3301.7673975706102
# ------第122个epoch------
# train_loss: -4439.1639234542845
# ------第123个epoch------
# train_loss: -3810.017308950424
# ------第124个epoch------
# train_loss: -4191.921025943756
# ------第125个epoch------
# train_loss: -4657.597878718376
# ------第126个epoch------
# train_loss: -3988.90727891922
# ------第127个epoch------
# train_loss: -4429.955618023872
# ------第128个epoch------
# train_loss: -4389.536388206482
# ------第129个epoch------
# train_loss: -3456.646876335144
# ------第130个epoch------
# train_loss: -3041.400914669037
# ------第131个epoch------
# train_loss: -3443.111910676956
# ------第132个epoch------
# train_loss: -5333.1488824367525
# ------第133个epoch------
# train_loss: -4816.963049697876
# ------第134个epoch------
# train_loss: -5886.875964164734
# ------第135个epoch------
# train_loss: -4602.673104429245
# ------第136个epoch------
# train_loss: -4432.63806438446
# ------第137个epoch------
# train_loss: -5209.3756658554075
# ------第138个epoch------
# train_loss: -4213.7143019676205
# ------第139个epoch------
# train_loss: -3170.1104360580443
# ------第140个epoch------
# train_loss: -5459.550039100647
# ------第141个epoch------
# train_loss: -5024.517733860016
# ------第142个epoch------
# train_loss: -6335.966088294983
# ------第143个epoch------
# train_loss: -4081.3581697463987
# ------第144个epoch------
# train_loss: -4590.912039852143
# ------第145个epoch------
# train_loss: -4975.5798122406
# ------第146个epoch------
# train_loss: -4487.355937385559
# ------第147个epoch------
# train_loss: -5817.8328699111935
# ------第148个epoch------
# train_loss: -4521.378364777565
# ------第149个epoch------
# train_loss: -5404.895639991761
# ------第150个epoch------
# train_loss: -6489.676044273377
# ------第151个epoch------
# train_loss: -6386.31548075676
# ------第152个epoch------
# train_loss: -4987.558749127388
# ------第153个epoch------
# train_loss: -5885.99780216217
# ------第154个epoch------
# train_loss: -6973.478742027282
# ------第155个epoch------
# train_loss: -5968.003588974476
# ------第156个epoch------
# train_loss: -6177.226541519165
# ------第157个epoch------
# train_loss: -5102.358092689514
# ------第158个epoch------
# train_loss: -7079.50014116764
# ------第159个epoch------
# train_loss: -6848.262180006504
# ------第160个epoch------
# train_loss: -6150.010567188263
# ------第161个epoch------
# train_loss: -8946.170609283447
# ------第162个epoch------
# train_loss: -7071.985584831238
# ------第163个epoch------
# train_loss: -7299.470309269428
# ------第164个epoch------
# train_loss: -5918.9794672966
# ------第165个epoch------
# train_loss: -5676.747731542588
# ------第166个epoch------
# train_loss: -7882.419061088562
# ------第167个epoch------
# train_loss: -8571.200016999244
# ------第168个epoch------
# train_loss: -7848.341234970093
# ------第169个epoch------
# train_loss: -6331.611383450031
# ------第170个epoch------
# train_loss: -7048.69349117279
# ------第171个epoch------
# train_loss: -7743.271297931671
# ------第172个epoch------
# train_loss: -7181.983211255074
# ------第173个epoch------
# train_loss: -7137.40831451416
# ------第174个epoch------
# train_loss: -7884.854024505616
# ------第175个epoch------
# train_loss: -7330.995793294906
# ------第176个epoch------
# train_loss: -7860.320407104492
# ------第177个epoch------
# train_loss: -8484.92528243065
# ------第178个epoch------
# train_loss: -8127.597458934784
# ------第179个epoch------
# train_loss: -8388.036378002167
# ------第180个epoch------
# train_loss: -8673.707046055793
# ------第181个epoch------
# train_loss: -8257.476397418975
# ------第182个epoch------
# train_loss: -9154.228986549377
# ------第183个epoch------
# train_loss: -8333.771356201172
# ------第184个epoch------
# train_loss: -10134.60586423874
# ------第185个epoch------
# train_loss: -9495.000353813171
# ------第186个epoch------
# train_loss: -7398.370262050628
# ------第187个epoch------
# train_loss: -10888.78407702446
# ------第188个epoch------
# train_loss: -8560.960749053955
# ------第189个epoch------
# train_loss: -10749.0035987854
# ------第190个epoch------
# train_loss: -8569.073630189896
# ------第191个epoch------
# train_loss: -8585.435171699524
# ------第192个epoch------
# train_loss: -9848.660045337678
# ------第193个epoch------
# train_loss: -8962.466602993012
# ------第194个epoch------
# train_loss: -9997.825830078125
# ------第195个epoch------
# train_loss: -10778.345822548867
# ------第196个epoch------
# train_loss: -8392.105760788918
# ------第197个epoch------
# train_loss: -10758.036107754708
# ------第198个epoch------
# train_loss: -9925.663371133804
# ------第199个epoch------
# train_loss: -8553.89255590439
# ------第200个epoch------
# train_loss: -8590.283799314499
# 24.29698156635166
# 24.412554268614162
# RMSE: 0.01129189419479012  ≈ 0.011292
# MAE : 0.0031031172552045847  ≈ 0.003103
# TER : 0.995265849652976  ≈ 0.995266
# ------第201个epoch------
# train_loss: -9027.028296375274
# ------第202个epoch------
# train_loss: -10788.848515701295
# ------第203个epoch------
# train_loss: -9613.98517589569
# ------第204个epoch------
# train_loss: -8429.114083766937
# ------第205个epoch------
# train_loss: -9511.379274940491
# ------第206个epoch------
# train_loss: -12300.700047683717
# ------第207个epoch------
# train_loss: -10975.805620002746
# ------第208个epoch------
# train_loss: -14332.856451225281
# ------第209个epoch------
# train_loss: -10451.486613178253
# ------第210个epoch------
# train_loss: -14482.25040550232
# ------第211个epoch------
# train_loss: -10653.061515021323
# ------第212个epoch------
# train_loss: -12110.754273366929
# ------第213个epoch------
# train_loss: -8666.705976009369
# ------第214个epoch------
# train_loss: -9805.455129003525
# ------第215个epoch------
# train_loss: -12941.313984107972
# ------第216个epoch------
# train_loss: -11250.211392974854
# ------第217个epoch------
# train_loss: -12589.422376441955
# ------第218个epoch------
# train_loss: -11877.330468273163
# ------第219个epoch------
# train_loss: -11316.539907836914
# ------第220个epoch------
# train_loss: -13089.647384881973
# ------第221个epoch------
# train_loss: -12895.39136724472
# ------第222个epoch------
# train_loss: -9198.456742095947
# ------第223个epoch------
# train_loss: -14964.633908629417
# ------第224个epoch------
# train_loss: -14472.953269720078
# ------第225个epoch------
# train_loss: -13749.892313957214
# ------第226个epoch------
# train_loss: -14589.480950272084
# ------第227个epoch------
# train_loss: -15479.186993265152
# ------第228个epoch------
# train_loss: -12670.66750383377
# ------第229个epoch------
# train_loss: -17520.40319776535
# ------第230个epoch------
# train_loss: -16910.826909446718
# ------第231个epoch------
# train_loss: -14155.221488380432
# ------第232个epoch------
# train_loss: -15824.193711948396
# ------第233个epoch------
# train_loss: -9656.075073242188
# ------第234个epoch------
# train_loss: -14567.42157239914
# ------第235个epoch------
# train_loss: -15551.1528945446
# ------第236个epoch------
# train_loss: -13831.257550621032
# ------第237个epoch------
# train_loss: -14021.74655866623
# ------第238个epoch------
# train_loss: -11923.555189609528
# ------第239个epoch------
# train_loss: -14841.522616195678
# ------第240个epoch------
# train_loss: -15713.435239505769
# ------第241个epoch------
# train_loss: -16028.795858430862
# ------第242个epoch------
# train_loss: -15310.221864414216
# ------第243个epoch------
# train_loss: -18236.52717628479
# ------第244个epoch------
# train_loss: -15598.900139713287
# ------第245个epoch------
# train_loss: -19197.08363647461
# ------第246个epoch------
# train_loss: -16071.365724658966
# ------第247个epoch------
# train_loss: -18695.07827014923
# ------第248个epoch------
# train_loss: -13618.742352199555
# ------第249个epoch------
# train_loss: -20818.058469963074
# ------第250个epoch------
# train_loss: -16912.812938976287
# ------第251个epoch------
# train_loss: -17489.705704069136
# ------第252个epoch------
# train_loss: -17262.8668715477
# ------第253个epoch------
# train_loss: -15616.262467956543
# ------第254个epoch------
# train_loss: -17015.401495838167
# ------第255个epoch------
# train_loss: -20155.761293983458
# ------第256个epoch------
# train_loss: -18808.01154088974
# ------第257个epoch------
# train_loss: -17838.67956328392
# ------第258个epoch------
# train_loss: -23720.99319934845
# ------第259个epoch------
# train_loss: -12804.05398826599
# ------第260个epoch------
# train_loss: -20138.981004953384
# ------第261个epoch------
# train_loss: -17799.482419204713
# ------第262个epoch------
# train_loss: -16442.653257846832
# ------第263个epoch------
# train_loss: -13340.493596696853
# ------第264个epoch------
# train_loss: -16803.290880155564
# ------第265个epoch------
# train_loss: -16649.409898602964
# ------第266个epoch------
# train_loss: -17855.76836452484
# ------第267个epoch------
# train_loss: -20135.969252061845
# ------第268个epoch------
# train_loss: -17664.662302350996
# ------第269个epoch------
# train_loss: -21030.46723423004
# ------第270个epoch------
# train_loss: -20626.012412166594
# ------第271个epoch------
# train_loss: -18374.602851486205
# ------第272个epoch------
# train_loss: -16439.8958278656
# ------第273个epoch------
# train_loss: -21017.34909186363
# ------第274个epoch------
# train_loss: -18284.448032546043
# ------第275个epoch------
# train_loss: -27455.68388519287
# ------第276个epoch------
# train_loss: -23520.303381252288
# ------第277个epoch------
# train_loss: -20312.44512834549
# ------第278个epoch------
# train_loss: -22329.537147903444
# ------第279个epoch------
# train_loss: -24579.14323797226
# ------第280个epoch------
# train_loss: -21700.50719203949
# ------第281个epoch------
# train_loss: -22975.331531190874
# ------第282个epoch------
# train_loss: -21562.947421741486
# ------第283个epoch------
# train_loss: -19545.5895339489
# ------第284个epoch------
# train_loss: -20557.204144477844
# ------第285个epoch------
# train_loss: -20968.20812740326
# ------第286个epoch------
# train_loss: -20436.73877372742
# ------第287个epoch------
# train_loss: -23775.090476989746
# ------第288个epoch------
# train_loss: -25990.33453216553
# ------第289个epoch------
# train_loss: -23087.124135875703
# ------第290个epoch------
# train_loss: -22151.481838989257
# ------第291个epoch------
# train_loss: -25305.383838176727
# ------第292个epoch------
# train_loss: -28026.081608843804
# ------第293个epoch------
# train_loss: -26079.155732631683
# ------第294个epoch------
# train_loss: -25451.24592819214
# ------第295个epoch------
# train_loss: -20759.722322273254
# ------第296个epoch------
# train_loss: -26875.24681968689
# ------第297个epoch------
# train_loss: -23747.267923736574
# ------第298个epoch------
# train_loss: -24127.494928741457
# ------第299个epoch------
# train_loss: -28629.13584485054
# ------第300个epoch------
# train_loss: -22844.461190986633
# ------第301个epoch------
# train_loss: -25160.280409431456
# ------第302个epoch------
# train_loss: -23762.57316467762
# ------第303个epoch------
# train_loss: -26213.792184185982
# ------第304个epoch------
# train_loss: -26747.613556671142
# ------第305个epoch------
# train_loss: -24890.733438062667
# ------第306个epoch------
# train_loss: -27716.112363624572
# ------第307个epoch------
# train_loss: -25268.11728925705
# ------第308个epoch------
# train_loss: -27529.980505561827
# ------第309个epoch------
# train_loss: -26402.920419692993
# ------第310个epoch------
# train_loss: -25017.7019361496
# ------第311个epoch------
# train_loss: -25791.93531165123
# ------第312个epoch------
# train_loss: -24951.451989078523
# ------第313个epoch------
# train_loss: -24862.75510072708
# ------第314个epoch------
# train_loss: -33122.52952589989
# ------第315个epoch------
# train_loss: -25910.69784787893
# ------第316个epoch------
# train_loss: -26982.15320663452
# ------第317个epoch------
# train_loss: -30228.2334025383
# ------第318个epoch------
# train_loss: -24116.747373962404
# ------第319个epoch------
# train_loss: -26940.277465307714
# ------第320个epoch------
# train_loss: -34150.06223068237
# ------第321个epoch------
# train_loss: -29622.76839339733
# ------第322个epoch------
# train_loss: -27771.096500205993
# ------第323个epoch------
# train_loss: -26439.759188520908
# ------第324个epoch------
# train_loss: -40074.29298901558
# ------第325个epoch------
# train_loss: -29426.64746621847
# ------第326个epoch------
# train_loss: -34301.170062446596
# ------第327个epoch------
# train_loss: -30498.51118707657
# ------第328个epoch------
# train_loss: -29520.820114707945
# ------第329个epoch------
# train_loss: -30120.712588596343
# ------第330个epoch------
# train_loss: -33264.33698215485
# ------第331个epoch------
# train_loss: -35501.76498794556
# ------第332个epoch------
# train_loss: -28066.96363143921
# ------第333个epoch------
# train_loss: -34728.5421790123
# ------第334个epoch------
# train_loss: -24136.936341285706
# ------第335个epoch------
# train_loss: -29681.323565077782
# ------第336个epoch------
# train_loss: -31803.371423339842
# ------第337个epoch------
# train_loss: -33826.2889626503
# ------第338个epoch------
# train_loss: -29691.364655685426
# ------第339个epoch------
# train_loss: -33517.622754645345
# ------第340个epoch------
# train_loss: -26540.743289375307
# ------第341个epoch------
# train_loss: -39398.21136293411
# ------第342个epoch------
# train_loss: -22597.093824386597
# ------第343个epoch------
# train_loss: -30652.67309217453
# ------第344个epoch------
# train_loss: -33384.99227180481
# ------第345个epoch------
# train_loss: -25959.295406246187
# ------第346个epoch------
# train_loss: -33296.30476417542
# ------第347个epoch------
# train_loss: -33763.55125246048
# ------第348个epoch------
# train_loss: -26893.83249320984
# ------第349个epoch------
# train_loss: -34690.27531814575
# ------第350个epoch------
# train_loss: -32397.855024528504
# ------第351个epoch------
# train_loss: -34424.901951408385
# ------第352个epoch------
# train_loss: -36520.485173416135
# ------第353个epoch------
# train_loss: -30772.099186444284
# ------第354个epoch------
# train_loss: -34591.494927692416
# ------第355个epoch------
# train_loss: -36563.45884361267
# ------第356个epoch------
# train_loss: -34238.32172627449
# ------第357个epoch------
# train_loss: -40354.66945772171
# ------第358个epoch------
# train_loss: -26578.353602015974
# ------第359个epoch------
# train_loss: -38890.879677963254
# ------第360个epoch------
# train_loss: -36354.52815532684
# ------第361个epoch------
# train_loss: -35050.2030616045
# ------第362个epoch------
# train_loss: -27869.6231842041
# ------第363个epoch------
# train_loss: -32149.84143009186
# ------第364个epoch------
# train_loss: -30026.039332485198
# ------第365个epoch------
# train_loss: -35568.808599472046
# ------第366个epoch------
# train_loss: -32258.584287643433
# ------第367个epoch------
# train_loss: -32688.98400592804
# ------第368个epoch------
# train_loss: -43697.19182682037
# ------第369个epoch------
# train_loss: -26822.0617893219
# ------第370个epoch------
# train_loss: -38850.479103803635
# ------第371个epoch------
# train_loss: -35280.22116661072
# ------第372个epoch------
# train_loss: -42967.54647293091
# ------第373个epoch------
# train_loss: -42293.30895390511
# ------第374个epoch------
# train_loss: -36872.89319734574
# ------第375个epoch------
# train_loss: -36933.31194286347
# ------第376个epoch------
# train_loss: -36774.97386302948
# ------第377个epoch------
# train_loss: -36742.06276435852
# ------第378个epoch------
# train_loss: -39824.248291015625
# ------第379个epoch------
# train_loss: -46985.435861587524
# ------第380个epoch------
# train_loss: -35164.485374712945
# ------第381个epoch------
# train_loss: -34866.26631259918
# ------第382个epoch------
# train_loss: -40786.405566215515
# ------第383个epoch------
# train_loss: -39426.7513074398
# ------第384个epoch------
# train_loss: -35904.99939632416
# ------第385个epoch------
# train_loss: -38028.21422977447
# ------第386个epoch------
# train_loss: -42085.37168207169
# ------第387个epoch------
# train_loss: -37836.64679031372
# ------第388个epoch------
# train_loss: -33347.941637420656
# ------第389个epoch------
# train_loss: -31798.925354003906
# ------第390个epoch------
# train_loss: -43403.54715576172
# ------第391个epoch------
# train_loss: -41495.71331537962
# ------第392个epoch------
# train_loss: -38766.759755897525
# ------第393个epoch------
# train_loss: -44546.725639533994
# ------第394个epoch------
# train_loss: -41496.620855903624
# ------第395个epoch------
# train_loss: -52470.43241014481
# ------第396个epoch------
# train_loss: -32372.21537876129
# ------第397个epoch------
# train_loss: -44915.407531452176
# ------第398个epoch------
# train_loss: -46094.17815561294
# ------第399个epoch------
# train_loss: -42741.41158390045
# ------第400个epoch------
# train_loss: -39425.73118801117
# 24.316908730445306
# 24.412554268614162
# RMSE: 0.01130115523933317  ≈ 0.011301
# MAE : 0.0031184723157770622  ≈ 0.003118
# TER : 0.996082116720911  ≈ 0.996082
# ------第401个epoch------
# train_loss: -44453.671743702886
# ------第402个epoch------
# train_loss: -42246.941080093384
# ------第403个epoch------
# train_loss: -41536.929920387265
# ------第404个epoch------
# train_loss: -52411.309540367125
# ------第405个epoch------
# train_loss: -43508.334003448486
# ------第406个epoch------
# train_loss: -38676.02515888214
# ------第407个epoch------
# train_loss: -40710.281313323976
# ------第408个epoch------
# train_loss: -49259.458198070526
# ------第409个epoch------
# train_loss: -53911.26561012268
# ------第410个epoch------
# train_loss: -53191.58662776947
# ------第411个epoch------
# train_loss: -50753.712451267245
# ------第412个epoch------
# train_loss: -53346.15522340536
# ------第413个epoch------
# train_loss: -52366.63108642101
# ------第414个epoch------
# train_loss: -47319.98862838745
# ------第415个epoch------
# train_loss: -51204.85120089054
# ------第416个epoch------
# train_loss: -55592.17880554199
# ------第417个epoch------
# train_loss: -41215.86523628235
# ------第418个epoch------
# train_loss: -52038.798583602904
# ------第419个epoch------
# train_loss: -40601.1710029602
# ------第420个epoch------
# train_loss: -47437.033896255496
# ------第421个epoch------
# train_loss: -49750.23853530884
# ------第422个epoch------
# train_loss: -46808.40494174957
# ------第423个epoch------
# train_loss: -42597.80213394165
# ------第424个epoch------
# train_loss: -46262.627530860904
# ------第425个epoch------
# train_loss: -40095.929906177524
# ------第426个epoch------
# train_loss: -37574.20952129364
# ------第427个epoch------
# train_loss: -63024.03907833099
# ------第428个epoch------
# train_loss: -57298.45269918442
# ------第429个epoch------
# train_loss: -49483.21909765005
# ------第430个epoch------
# train_loss: -44713.82241821289
# ------第431个epoch------
# train_loss: -42823.431366086006
# ------第432个epoch------
# train_loss: -49422.697708892825
# ------第433个epoch------
# train_loss: -57027.97696247101
# ------第434个epoch------
# train_loss: -59541.144446992876
# ------第435个epoch------
# train_loss: -57246.605061149596
# ------第436个epoch------
# train_loss: -59360.45455219746
# ------第437个epoch------
# train_loss: -41069.94137039185
# ------第438个epoch------
# train_loss: -57339.73194627762
# ------第439个epoch------
# train_loss: -53555.51215553284
# ------第440个epoch------
# train_loss: -41514.74826946259
# ------第441个epoch------
# train_loss: -52477.662925338744
# ------第442个epoch------
# train_loss: -40706.53261051178
# ------第443个epoch------
# train_loss: -49814.47977838516
# ------第444个epoch------
# train_loss: -43863.74845790863
# ------第445个epoch------
# train_loss: -60206.308622646335
# ------第446个epoch------
# train_loss: -45709.10128210411
# ------第447个epoch------
# train_loss: -45485.3003819108
# ------第448个epoch------
# train_loss: -59918.96260528565
# ------第449个epoch------
# train_loss: -59627.59780807495
# ------第450个epoch------
# train_loss: -60794.08236618042
# ------第451个epoch------
# train_loss: -67256.51479148865
# ------第452个epoch------
# train_loss: -51410.307837104796
# ------第453个epoch------
# train_loss: -54228.671142196654
# ------第454个epoch------
# train_loss: -49017.89458380938
# ------第455个epoch------
# train_loss: -60651.11954932213
# ------第456个epoch------
# train_loss: -45755.91349487305
# ------第457个epoch------
# train_loss: -52992.33480911255
# ------第458个epoch------
# train_loss: -58170.77690318823
# ------第459个epoch------
# train_loss: -58770.938362312314
# ------第460个epoch------
# train_loss: -62275.9427028656
# ------第461个epoch------
# train_loss: -47354.742870235445
# ------第462个epoch------
# train_loss: -63316.19033956528
# ------第463个epoch------
# train_loss: -69403.68284301758
# ------第464个epoch------
# train_loss: -61417.35567245483
# ------第465个epoch------
# train_loss: -58474.89119338989
# ------第466个epoch------
# train_loss: -59154.273749923705
# ------第467个epoch------
# train_loss: -78590.08647727966
# ------第468个epoch------
# train_loss: -55631.1670224905
# ------第469个epoch------
# train_loss: -54218.935335922244
# ------第470个epoch------
# train_loss: -49620.90600509643
# ------第471个epoch------
# train_loss: -64656.65416383743
# ------第472个epoch------
# train_loss: -51819.75899953842
# ------第473个epoch------
# train_loss: -61738.90857505798
# ------第474个epoch------
# train_loss: -52170.61014633179
# ------第475个epoch------
# train_loss: -64377.82187683582
# ------第476个epoch------
# train_loss: -58984.3375669837
# ------第477个epoch------
# train_loss: -63175.43953113556
# ------第478个epoch------
# train_loss: -68436.50911483765
# ------第479个epoch------
# train_loss: -57404.67351856232
# ------第480个epoch------
# train_loss: -63845.70819168091
# ------第481个epoch------
# train_loss: -78373.29537658692
# ------第482个epoch------
# train_loss: -71486.01257572175
# ------第483个epoch------
# train_loss: -64295.37840499878
# ------第484个epoch------
# train_loss: -59373.199440920354
# ------第485个epoch------
# train_loss: -65476.53627557754
# ------第486个epoch------
# train_loss: -54424.45947723389
# ------第487个epoch------
# train_loss: -56771.52902383804
# ------第488个epoch------
# train_loss: -62932.50574645996
# ------第489个epoch------
# train_loss: -80464.09027290344
# ------第490个epoch------
# train_loss: -77271.87227740287
# ------第491个epoch------
# train_loss: -60810.04982175827
# ------第492个epoch------
# train_loss: -76589.4052597046
# ------第493个epoch------
# train_loss: -58004.220973587035
# ------第494个epoch------
# train_loss: -67111.93848609924
# ------第495个epoch------
# train_loss: -71651.41003379822
# ------第496个epoch------
# train_loss: -45554.75231819153
# ------第497个epoch------
# train_loss: -53976.60680980682
# ------第498个epoch------
# train_loss: -56056.073521101476
# ------第499个epoch------
# train_loss: -74768.22121620178
# ------第500个epoch------
# train_loss: -78908.35386390686
# ------第501个epoch------
# train_loss: -74425.3279045105
# ------第502个epoch------
# train_loss: -69468.36268615723
# ------第503个epoch------
# train_loss: -84482.4950876236
# ------第504个epoch------
# train_loss: -76201.50558195115
# ------第505个epoch------
# train_loss: -76911.48164424897
# ------第506个epoch------
# train_loss: -60603.19682047367
# ------第507个epoch------
# train_loss: -58982.0367565155
# ------第508个epoch------
# train_loss: -72603.38007774352
# ------第509个epoch------
# train_loss: -85599.10107631683
# ------第510个epoch------
# train_loss: -72246.16013526917
# ------第511个epoch------
# train_loss: -69554.4245016098
# ------第512个epoch------
# train_loss: -78890.83464813232
# ------第513个epoch------
# train_loss: -60390.53690910339
# ------第514个epoch------
# train_loss: -67190.15665426254
# ------第515个epoch------
# train_loss: -56919.22168807984
# ------第516个epoch------
# train_loss: -82712.0778521061
# ------第517个epoch------
# train_loss: -76557.19645042419
# ------第518个epoch------
# train_loss: -67986.53487896919
# ------第519个epoch------
# train_loss: -78864.26787376404
# ------第520个epoch------
# train_loss: -81869.58841476441
# ------第521个epoch------
# train_loss: -72847.33509426117
# ------第522个epoch------
# train_loss: -75426.0253051281
# ------第523个epoch------
# train_loss: -72092.32860069275
# ------第524个epoch------
# train_loss: -91495.98603625297
# ------第525个epoch------
# train_loss: -71930.746748209
# ------第526个epoch------
# train_loss: -79731.891533494
# ------第527个epoch------
# train_loss: -77439.06158370971
# ------第528个epoch------
# train_loss: -102830.49489632846
# ------第529个epoch------
# train_loss: -75515.20551152229
# ------第530个epoch------
# train_loss: -72103.71494045257
# ------第531个epoch------
# train_loss: -77150.88208160401
# ------第532个epoch------
# train_loss: -88991.46501512527
# ------第533个epoch------
# train_loss: -71934.42290382386
# ------第534个epoch------
# train_loss: -84658.8223745346
# ------第535个epoch------
# train_loss: -91161.80272102356
# ------第536个epoch------
# train_loss: -78024.71969623565
# ------第537个epoch------
# train_loss: -74993.24771652222
# ------第538个epoch------
# train_loss: -102547.30671310425
# ------第539个epoch------
# train_loss: -102431.1283648491
# ------第540个epoch------
# train_loss: -73001.66211709977
# ------第541个epoch------
# train_loss: -76914.07847442626
# ------第542个epoch------
# train_loss: -71053.9434589386
# ------第543个epoch------
# train_loss: -80639.25227584838
# ------第544个epoch------
# train_loss: -81859.94869494438
# ------第545个epoch------
# train_loss: -74042.73299171924
# ------第546个epoch------
# train_loss: -88800.4945652008
# ------第547个epoch------
# train_loss: -82330.60316028594
# ------第548个epoch------
# train_loss: -87894.75516777039
# ------第549个epoch------
# train_loss: -84405.43755149841
# ------第550个epoch------
# train_loss: -94284.23916754723
# ------第551个epoch------
# train_loss: -85285.39656295776
# ------第552个epoch------
# train_loss: -90296.23773880005
# ------第553个epoch------
# train_loss: -79346.55784111023
# ------第554个epoch------
# train_loss: -97275.71846727729
# ------第555个epoch------
# train_loss: -98592.72369422912
# ------第556个epoch------
# train_loss: -92540.87600288392
# ------第557个epoch------
# train_loss: -93663.90745105743
# ------第558个epoch------
# train_loss: -86085.795287323
# ------第559个epoch------
# train_loss: -79756.26542806625
# ------第560个epoch------
# train_loss: -79499.68636344672
# ------第561个epoch------
# train_loss: -104755.03251457214
# ------第562个epoch------
# train_loss: -80314.85484924316
# ------第563个epoch------
# train_loss: -84482.40152168274
# ------第564个epoch------
# train_loss: -88267.22888908387
# ------第565个epoch------
# train_loss: -69213.58295090198
# ------第566个epoch------
# train_loss: -105736.21518325806
# ------第567个epoch------
# train_loss: -72384.41404857635
# ------第568个epoch------
# train_loss: -96632.24439544677
# ------第569个epoch------
# train_loss: -119644.25128440857
# ------第570个epoch------
# train_loss: -97806.04659423829
# ------第571个epoch------
# train_loss: -64304.57644224167
# ------第572个epoch------
# train_loss: -73253.66059513092
# ------第573个epoch------
# train_loss: -89843.3257364273
# ------第574个epoch------
# train_loss: -97338.25384641885
# ------第575个epoch------
# train_loss: -84474.97528958917
# ------第576个epoch------
# train_loss: -77110.70505371093
# ------第577个epoch------
# train_loss: -109598.03738574982
# ------第578个epoch------
# train_loss: -103217.17615814209
# ------第579个epoch------
# train_loss: -99093.03997573853
# ------第580个epoch------
# train_loss: -88265.50766582489
# ------第581个epoch------
# train_loss: -98695.7447265625
# ------第582个epoch------
# train_loss: -87507.6497756958
# ------第583个epoch------
# train_loss: -109727.39475536346
# ------第584个epoch------
# train_loss: -92299.88060693741
# ------第585个epoch------
# train_loss: -87367.07792491913
# ------第586个epoch------
# train_loss: -101899.30390222072
# ------第587个epoch------
# train_loss: -92399.11951830387
# ------第588个epoch------
# train_loss: -96888.97084770203
# ------第589个epoch------
# train_loss: -88100.5559841156
# ------第590个epoch------
# train_loss: -100219.72090911865
# ------第591个epoch------
# train_loss: -102680.16067752839
# ------第592个epoch------
# train_loss: -102682.90885467529
# ------第593个epoch------
# train_loss: -104024.53685493469
# ------第594个epoch------
# train_loss: -95850.38778076172
# ------第595个epoch------
# train_loss: -118118.0460468769
# ------第596个epoch------
# train_loss: -111062.79340438843
# ------第597个epoch------
# train_loss: -101789.15950276851
# ------第598个epoch------
# train_loss: -90715.41377182007
# ------第599个epoch------
# train_loss: -91312.49447607994
# ------第600个epoch------
# train_loss: -92276.63786315918
# 24.316550420032744
# 24.412554268614162
# RMSE: 0.011300988716456389  ≈ 0.011301
# MAE : 0.0031216838179277057  ≈ 0.003122
# TER : 0.9960674394196906  ≈ 0.996067
# ------Finished------

# %%
torch.cuda.empty_cache()

# %%
#dataset = np.loadtxt(fname='E:/data/Abilene.txt', delimiter="\t", skiprows=1)

# %%
#train_index = np.random.choice(list(range(dataset.shape[0])), size = int(0.7*dataset.shape[0]), replace=False)
#test_index = list(set(range(dataset.shape[0])) - set(train_index))

# %%
#np.savetxt('E:/data/Abilene_train.txt', dataset[train_index,:])
#np.savetxt('E:/data/Abilene_test.txt', dataset[test_index,:])
